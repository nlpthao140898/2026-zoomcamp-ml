# %% [markdown]
# # 2025-cohort-homework
# For this homework, we will use car fuel efficiency dataset to create a regression model for predicting the car fuel efficiency (column 'fuel_efficiency_mpg)
# <br>
# Q1. horsepower
# <br>
# Q2. 149
# <br>
# Q3. with mean
# <br>
# Q4. 0

# %%
data1 = 'https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv'

# %%
# !pip install wget

# %%
# !wget $data1

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('car_fuel_efficiency.csv')
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# 3            16.912736
# 4            12.488369

# %%
df.isnull().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df['horsepower'].mean()
# Out:
# np.float64(149.65729212983547)

# %%
df['horsepower'].median()
# Out:
# np.float64(149.0)

# %%
np.random.seed(42)

# %%
idx = np.arange(len(df))
idx
np.random.shuffle(idx)
print(idx)
# Out:
# [ 483 7506 8795 ... 5390  860 7270]

# %%
df = df.iloc[idx]
df.head()
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 483                   220            3.0       144.0     2535.887591
# 7506                  160            2.0       141.0     2741.170484
# 8795                  230            3.0       155.0     2471.880237
# 1688                  150            3.0       206.0     3748.164469
# 6217                  300            4.0       111.0     2135.716359
#
#       acceleration  model_year origin fuel_type         drivetrain  num_doors  \
# 483           18.7        2009    USA  Gasoline    All-wheel drive        2.0
# 7506          14.3        2019   Asia    Diesel  Front-wheel drive        2.0
# 8795           NaN        2017   Asia    Diesel  Front-wheel drive        2.0
# 1688          15.5        2015    USA  Gasoline    All-wheel drive        1.0
# 6217          16.9        2006    USA  Gasoline    All-wheel drive        NaN
#
#       fuel_efficiency_mpg
# 483             16.642943
# 7506            16.298377
# 8795            18.591822
# 1688            11.818843
# 6217            19.402209

# %%
df.reset_index(drop=True)
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     220            3.0       144.0     2535.887591
# 1                     160            2.0       141.0     2741.170484
# 2                     230            3.0       155.0     2471.880237
# 3                     150            3.0       206.0     3748.164469
# 4                     300            4.0       111.0     2135.716359
# ...                   ...            ...         ...             ...
# 9699                  210            2.0       163.0     1972.029124
# 9700                  160            4.0       126.0     3011.588014
# 9701                  290            7.0       187.0     2440.508039
# 9702                  260            2.0       129.0     1865.404480
# 9703                  270            1.0       147.0     2611.939500
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             18.7        2009     USA  Gasoline    All-wheel drive
# 1             14.3        2019    Asia    Diesel  Front-wheel drive
# 2              NaN        2017    Asia    Diesel  Front-wheel drive
# 3             15.5        2015     USA  Gasoline    All-wheel drive
# 4             16.9        2006     USA  Gasoline    All-wheel drive
# ...            ...         ...     ...       ...                ...
# 9699          14.4        2011  Europe    Diesel    All-wheel drive
# 9700          16.4        2009  Europe    Diesel    All-wheel drive
# 9701           NaN        2019     USA  Gasoline    All-wheel drive
# 9702          14.5        2019  Europe  Gasoline  Front-wheel drive
# 9703          11.7        2017    Asia    Diesel  Front-wheel drive
#
#       num_doors  fuel_efficiency_mpg
# 0           2.0            16.642943
# 1           2.0            16.298377
# 2           2.0            18.591822
# 3           1.0            11.818843
# 4           NaN            19.402209
# ...         ...                  ...
# 9699        1.0            19.961672
# 9700       -1.0            14.651056
# 9701       -1.0            18.404435
# 9702        0.0            20.502460
# 9703        0.0            16.816241
#
# [9704 rows x 11 columns]

# %%
n = len(df)
n_train = int(n*0.6)
n_val = int(n*0.2)
n_test = n - n_train - n_val
n_train, n_val, n_test
# Out:
# (5822, 1940, 1942)

# %%
n
# Out:
# 9704

# %%
df_train = df.iloc[:n_train]
df_val = df.iloc[n_train:n_train+n_val]
df_test = df.iloc[n_train+n_val:]

# %% [markdown]
# ## Train a linear regression model

# %%
def train_linear_regression(X,y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones,X])
    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)
    return w_full[0], w_full[1:]

# %% [markdown]
# ## Baseline model

# %%
df_train.columns
# Out:
# Index(['engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'model_year', 'origin', 'fuel_type', 'drivetrain',
#        'num_doors', 'fuel_efficiency_mpg'],
#       dtype='str')

# %%
df_train_filled_0 = df_train.copy()
df_train_filled_mean = df_train.copy()

# %%
df_train_filled_0['horsepower'] = df_train_filled_0['horsepower'].fillna(0)
df_train_filled_mean['horsepower'] = df_train_filled_mean['horsepower'].fillna(df_train['horsepower'].mean())

# %%
df_train.dtypes
# Out:
# engine_displacement      int64
# num_cylinders          float64
# horsepower             float64
# vehicle_weight         float64
# acceleration           float64
# model_year               int64
# origin                     str
# fuel_type                  str
# drivetrain                 str
# num_doors              float64
# fuel_efficiency_mpg    float64
# dtype: object

# %%
base = ['engine_displacement',
        'horsepower',
        'vehicle_weight',
        'model_year',
        'num_doors']
df_train[base]
# Out:
#       engine_displacement  horsepower  vehicle_weight  model_year  num_doors
# 483                   220       144.0     2535.887591        2009        2.0
# 7506                  160       141.0     2741.170484        2019        2.0
# 8795                  230       155.0     2471.880237        2017        2.0
# 1688                  150       206.0     3748.164469        2015        1.0
# 6217                  300       111.0     2135.716359        2006        NaN
# ...                   ...         ...             ...         ...        ...
# 8387                  160       111.0     3038.134712        2002        0.0
# 7331                  160       157.0     2877.624938        2006       -1.0
# 1696                  260       139.0     2606.972984        2009       -1.0
# 5685                  280       132.0     4004.214323        2014        2.0
# 6735                  210       152.0     2500.175687        2020        0.0
#
# [5822 rows x 5 columns]

# %%
X_train = df_train[base].values
X_train
# Out:
# array([[ 2.20000000e+02,  1.44000000e+02,  2.53588759e+03,
#          2.00900000e+03,  2.00000000e+00],
#        [ 1.60000000e+02,  1.41000000e+02,  2.74117048e+03,
#          2.01900000e+03,  2.00000000e+00],
#        [ 2.30000000e+02,  1.55000000e+02,  2.47188024e+03,
#          2.01700000e+03,  2.00000000e+00],
#        ...,
#        [ 2.60000000e+02,  1.39000000e+02,  2.60697298e+03,
#          2.00900000e+03, -1.00000000e+00],
#        [ 2.80000000e+02,  1.32000000e+02,  4.00421432e+03,
#          2.01400000e+03,  2.00000000e+00],
#        [ 2.10000000e+02,  1.52000000e+02,  2.50017569e+03,
#          2.02000000e+03,  0.00000000e+00]], shape=(5822, 5))

# %%
X_train = df_train[base].fillna(0).values

# %%
y_train = df_train['fuel_efficiency_mpg'].values

# %%
w0,w=train_linear_regression(X_train,y_train)
w0,w
# Out:
# (np.float64(28.781317196819824),
#  array([ 0.00010096,  0.00354136, -0.0050131 ,  0.00036552,  0.00651394]))

# %%
y_pred = w0 + X_train.dot(w)

# %%
import seaborn as sns
sns.histplot(y_pred, bins = 50, color = 'blue', alpha = 0.5, label = 'predicted')
sns.histplot(y_train, bins = 50, color ='red', alpha = 0.5, label = 'actual')
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# RMSE

# %%
def rmse(y, y_pred):
    error = y -  y_pred
    se = error **2
    mse = se.mean()
    return np.sqrt(mse)

# %%
rmse(y_train, y_pred)
# Out:
# np.float64(0.5203033631111)

# %%
X_train_mean = df_train[base].fillna(df_train[base].mean()).values

# %%
w0,w = train_linear_regression(X_train_mean, y_train)

# %%
y_pred1 = w0 + X_train_mean.dot(w)

# %%
rmse(y_pred1, y_train)
# Out:
# np.float64(0.4624229221688031)

# %% [markdown]
# Q4. train a regularized linear regression
# fill the NAs with 0
# which r gives the best RMSE?

# %%
X_train = df_train[base].fillna(0).values

# %%
import numpy as np
def train_linear_regression(X,y,r):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones,X])

    XTX = X.T.dot(X)
    XTX = XTX + r*np.eye(XTX.shape[0])

    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)

    return w_full[0], w_full[1:]

# %%
r = 1
w0,w = train_linear_regression(X_train, y_train, r)
print(w0,w)
y_pred = w0 + X_train.dot(w)
rmse_temp = rmse(y_pred, y_train)
# Out:
# 1.7275356647951328 [ 0.00014989  0.00354085 -0.00500742  0.01380198  0.0078019 ]

# %%
r_test = [0, 0.01, 0.1, 1, 5, 10, 100]
rmse_best = 10000
best_r = None
for r in r_test:
    w0,w = train_linear_regression(X_train, y_train, r)
    y_pred = w0 + X_train.dot(w)
    rmse_temp = rmse(y_pred, y_train)
    print(rmse_temp)
    if rmse_temp < rmse_best:
        rmse_best = rmse_temp
        best_r = r
    else:
        continue
best_r
# Out:
# 0.5203033631111
# 0.5204634033108387
# 0.5235451728397318
# 0.5279612694411779
# 0.528746955093025
# 0.5288535756029592
# 0.5289512814451854
# 0

# %% [markdown]
# Q5. We used seed 42 for splitting the data. Let's find out how selecting the seed influences our score
